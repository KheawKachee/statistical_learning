# %% [markdown]
# ## Logistic regression and neural network

# %% [markdown]
# - [Data processing](#data-processing)
# - [Logistic regression](#logistic-regression)
#     - [Training](#logistic-regression-training)
#     - [Training and validation loss](#training-vs-validation-loss-logistic-regression)
#     - [Evaluation](#logistic-regression-evaluation)
# - [Neural network](#neural-network)
#     - [Training](#neural-network-training)
#     - [Training and validation loss](#training-vs-valid-loss-neural-network)
#     - [Evaluation](#neural-network-evaluation)

# %% [markdown]
# ## Data processing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import seaborn as sns


def train_validate_test_split(df, train_percent=0.6, validate_percent=0.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(np.floor(int(train_percent * m)))
    validate_end = int(np.floor(int(validate_percent * m) + train_end))

    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]

    train = train.reset_index(drop=True)
    validate = validate.reset_index(drop=True)
    test = test.reset_index(drop=True)

    return train, validate, test

# %% [markdown]
# ### Data spliting and loading

# %%
foldername = "archive"
df = pd.read_csv("%s/Student Depression Dataset.csv" % foldername)
df.keys()
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
target_column = ["Depression"]
feat_column = [
    "Gender",
    "Age",
    "City",
    "Profession",
    "Academic Pressure",
    "Work Pressure",
    "CGPA",
    "Study Satisfaction",
    "Job Satisfaction",
    "Sleep Duration",
    "Dietary Habits",
    "Degree",
    "Have you ever had suicidal thoughts ?",
    "Work/Study Hours",
    "Financial Stress",
    "Family History of Mental Illness",
]

# %%
all_column = target_column + feat_column
df = df[all_column]
df = df.apply(LabelEncoder().fit_transform)


train_df, test_df, valid_df = train_validate_test_split(
    df, train_percent=0.8, validate_percent=0.1, seed=None
)

X_scaler = StandardScaler()
train_df[feat_column].values[:] = X_scaler.fit_transform(train_df[feat_column].values[:])
test_df[feat_column].values[:] = X_scaler.transform(test_df[feat_column].values[:])
valid_df[feat_column].values[:] = X_scaler.transform(valid_df[feat_column].values[:])

print("# Training   dataset: %d" % len(train_df))
print("# Testing    dataset: %d" % len(test_df))
print("# Validating dataset: %d" % len(valid_df))
# Out:
# # Training   dataset: 22320
# # Testing    dataset: 2790
# # Validating dataset: 2791

# %%
all_column = target_column + feat_column
train_enc = train_df[all_column]

# %%
plt.figure(figsize=(12, 10))
cor = train_enc.corr()
g = sns.heatmap(cor, annot=True, cmap=plt.cm.cool)
g.axes.xaxis.set_ticks_position("top")
plt.setp(g.axes.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# ## Data loader

# %%
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader


class DataFrameDataset(Dataset):
    def __init__(self, df, features, target):
        self.df = df
        self.features = features
        self.target = target

        print(
            "[Target = 1]: %d [Target = 0]: %d"
            % (
                len(df[target_column][(df[target_column].values == 1)]),
                len(df[target_column][(df[target_column].values == 0)]),
            )
        )

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        x = torch.tensor(row[self.features].values).to(torch.float)
        y = torch.tensor(row[self.target].values).to(torch.float)
        return x, y


print("Num feat. column = %d" % len(feat_column))
train_set = DataFrameDataset(train_df, features=feat_column, target=target_column)
valid_set = DataFrameDataset(valid_df, features=feat_column, target=target_column)
test_set = DataFrameDataset(test_df, features=feat_column, target=target_column)
# Out:
# Num feat. column = 16
# [Target = 1]: 13058 [Target = 0]: 9262
# [Target = 1]: 1646 [Target = 0]: 1145
# [Target = 1]: 1632 [Target = 0]: 1158

# %% [markdown]
# ## Neural network and training

# %%
from tqdm import tqdm
import torch.optim as optim
from torchmetrics.classification import BinaryF1Score
import os

model_name = "NeuralNet"


class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.ep = 0
        self.min_validation_loss = float("inf")
        self.weight = torch.empty((1, 1), dtype=torch.int64)

    def check(self, weight, ep, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
            self.weight = weight
            self.ep = ep
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False


class NeuralNetwork(nn.Module):
    # build the constructor
    def __init__(
        self,
        n_inputs,
        n_outputs=1,
        n_hidden=1,
        num_layers=1,
        learning_rate=0.001,
        max_epoch=1000,
        model_folder=model_name,
        patience=1,
    ):
        super(NeuralNetwork, self).__init__()

        if num_layers == 1:
            model_list = []
            model_list.append(nn.Linear(n_inputs, n_outputs))
            model_list.append(nn.Sigmoid())
            self.model = nn.Sequential(*model_list)

        elif num_layers == 2:
            model_list = []
            model_list.append(nn.Linear(n_inputs, n_hidden))
            model_list.append(nn.Linear(n_hidden, n_outputs))
            model_list.append(nn.Sigmoid())

            self.model = nn.Sequential(*model_list)

        else:
            model_list = []
            model_list.append(nn.Linear(n_inputs, n_hidden))
            for i in range(num_layers - 2):
                model_list.append(nn.Linear(n_hidden, n_hidden))
            model_list.append(nn.Linear(n_hidden, n_outputs))
            model_list.append(nn.Sigmoid())
            self.model = nn.Sequential(*model_list)

        self.max_epoch = max_epoch
        self.criterion = nn.BCELoss()
        self.F1_score = BinaryF1Score()
        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)

        self.model_folder = model_folder
        os.makedirs(self.model_folder, exist_ok=True)

        self.Earlystoper = EarlyStopper(patience=patience)

    def forward(self, x):
        y_pred = self.model(x)
        return y_pred

    def train(self, train_set, valid_set, threshold, batch_size):

        training_avg_bce_list = []
        training_avg_f1_list = []

        valid_avg_bce_list = []
        valid_avg_f1_list = []

        validloader = DataLoader(valid_set, batch_size=batch_size, shuffle=False, drop_last=True)

        for epoch in range(self.max_epoch):  # loop over the dataset multiple times
            trainloader = DataLoader(train_set, batch_size=batch_size, shuffle=True, drop_last=True)
            pbar = tqdm(trainloader)

            self.model.train()
            mode = "TRAIN"
            loss_list = []
            f1_score_list = []

            for data in pbar:
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data

                # zero the parameter gradients
                self.optimizer.zero_grad()

                # forward + backward + optimize
                predictions = self.model(inputs)

                loss = self.criterion(predictions, labels)
                loss.backward()
                self.optimizer.step()

                loss_list.append(loss.item())

                pred_binary = 1 * (predictions > threshold)

                f1_score = self.F1_score(pred_binary, labels)
                f1_score_list.append(f1_score.item())

                pbar.set_description(
                    "%d [%s : %s] BIC Loss %0.3f, F1 score %0.3f"
                    % (
                        epoch,
                        mode,
                        model_name,
                        sum(loss_list) / len(loss_list),
                        sum(f1_score_list) / len(f1_score_list),
                    )
                )

            loss_list = []
            f1_score_list = []
            mode = "VALID"
            self.model.eval()
            vpbar = tqdm(validloader)
            for i, data in enumerate(vpbar):
                inputs, labels = data

                with torch.no_grad():
                    predictions = self.model(inputs)

                loss = self.criterion(predictions, labels)
                loss_list.append(loss.item())

                pred_binary = 1 * (predictions >= threshold)

                f1_score = self.F1_score(pred_binary, labels)
                f1_score_list.append(f1_score.item())

                vpbar.set_description(
                    "%d [%s : %s] BIC Loss %0.3f, F1 score %0.3f"
                    % (
                        epoch,
                        mode,
                        model_name,
                        sum(loss_list) / len(loss_list),
                        sum(f1_score_list) / len(f1_score_list),
                    )
                )

            training_avg_bce_list.append(sum(loss_list) / len(loss_list))
            training_avg_f1_list.append(sum(f1_score_list) / len(f1_score_list))
            valid_avg_bce_list.append(sum(loss_list) / len(loss_list))
            valid_avg_f1_list.append(sum(f1_score_list) / len(f1_score_list))

            stopping_criterion_met = self.Earlystoper.check(
                self.model.state_dict(), epoch, sum(loss_list) / len(loss_list)
            )

            if stopping_criterion_met:
                torch.save(self.model.state_dict(), "%s/%s.pth" % (self.model_folder, model_name))
                break

        best_ep = self.Earlystoper
        return (
            training_avg_bce_list,
            training_avg_f1_list,
            valid_avg_bce_list,
            valid_avg_f1_list,
            best_ep,
        )

# %%
from tqdm import tqdm
import pandas as pd
import os

n_hidden = 16
num_layers = 2

n_inputs = len(feat_column)
learning_rate = 0.0001
batch_size = 512
max_epoch = 100
model_folder = "NeuralNetwork-weights"

threshold = 0.5
patience = 1


results = []

for num_layers in [1, 2, 3]:
    neuralnet_model = NeuralNetwork(
        n_inputs,
        n_outputs=1,
        n_hidden=n_hidden,
        num_layers=num_layers,
        learning_rate=learning_rate,
        max_epoch=max_epoch,
        model_folder=model_folder,
        patience=patience,
    )

    (
        training_avg_bce_list,
        training_avg_f1_list,
        valid_avg_bce_list,
        valid_avg_f1_list,
        best_ep,
    ) = neuralnet_model.train(train_set, valid_set, threshold, batch_size)

    results.append({
        "num_layers": num_layers,
        "best_epoch": best_ep,
        "train_bce": training_avg_bce_list,
        "train_f1": training_avg_f1_list,
        "valid_bce": valid_avg_bce_list,
        "valid_f1_": valid_avg_f1_list,
        "best_valid_bce": min(valid_avg_bce_list),
        "best_valid_f1": max(valid_avg_f1_list),
    })

results_df = pd.DataFrame(results)
# Out:
# 0 [TRAIN : NeuralNet] BIC Loss 1.935, F1 score 0.031: 100%|██████████| 43/43 [00:07<00:00,  6.01it/s]
# 0 [VALID : NeuralNet] BIC Loss 1.738, F1 score 0.077: 100%|██████████| 5/5 [00:00<00:00,  6.00it/s]
# 1 [TRAIN : NeuralNet] BIC Loss 1.514, F1 score 0.149: 100%|██████████| 43/43 [00:07<00:00,  6.14it/s]
# 1 [VALID : NeuralNet] BIC Loss 1.402, F1 score 0.225: 100%|██████████| 5/5 [00:00<00:00,  5.77it/s]
# 2 [TRAIN : NeuralNet] BIC Loss 1.289, F1 score 0.310: 100%|██████████| 43/43 [00:07<00:00,  5.81it/s]
# 86 [TRAIN : NeuralNet] BIC Loss 0.415, F1 score 0.852: 100%|██████████| 43/43 [00:07<00:00,  5.60it/s]
# 86 [VALID : NeuralNet] BIC Loss 0.402, F1 score 0.854: 100%|██████████| 5/5 [00:00<00:00,  6.18it/s]
# 87 [TRAIN : NeuralNet] BIC Loss 0.414, F1 score 0.851: 100%|██████████| 43/43 [00:07<00:00,  6.04it/s]
# 87 [VALID : NeuralNet] BIC Loss 0.401, F1 score 0.852: 100%|██████████| 5/5 [00:00<00:00,  6.27it/s]
# 88 [TRAIN : NeuralNet] BIC Loss 0.413, F1 score 0.852: 100%|██████████| 43/43 [00:07<00:00,  6.05it/s]
# 88 [VALID : NeuralNet] BIC Loss 0.402, F1 score 0.853: 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 0 [TRAIN : NeuralNet] BIC Loss 1.496, F1 score 0.223: 100%|██████████| 43/43 [00:07<00:00,  5.69it/s]
# 0 [VALID : NeuralNet] BIC Loss 0.794, F1 score 0.613: 100%|██████████| 5/5 [00:01<00:00,  3.11it/s]
# 1 [TRAIN : NeuralNet] BIC Loss 0.788, F1 score 0.613: 100%|██████████| 43/43 [00:08<00:00,  5.20it/s]
# 1 [VALID : NeuralNet] BIC Loss 0.765, F1 score 0.590: 100%|██████████| 5/5 [00:00<00:00,  5.98it/s]
# 2 [TRAIN : NeuralNet] BIC Loss 0.757, F1 score 0.602: 100%|██████████| 43/43 [00:06<00:00,  6.31it/s]
# 2 [VALID : NeuralNet] BIC Loss 0.740, F1 score 0.616: 100%|██████████| 5/5 [00:00<00:00,  6.22it/s]
# 3 [TRAIN : NeuralNet] BIC Loss 0.735, F1 score 0.616: 100%|██████████| 43/43 [00:07<00:00,  5.88it/s]
# 3 [VALID : NeuralNet] BIC Loss 0.720, F1 score 0.640: 100%|██████████| 5/5 [00:00<00:00,  5.00it/s]
# 4 [TRAIN : NeuralNet] BIC Loss 0.718, F1 score 0.636: 100%|██████████| 43/43 [00:06<00:00,  6.44it/s]
# 4 [VALID : NeuralNet] BIC Loss 0.705, F1 score 0.655: 100%|██████████| 5/5 [00:00<00:00,  6.27it/s]
# 5 [TRAIN : NeuralNet] BIC Loss 0.705, F1 score 0.655: 100%|██████████| 43/43 [00:07<00:00,  5.43it/s]
# 5 [VALID : NeuralNet] BIC Loss 0.693, F1 score 0.680: 100%|██████████| 5/5 [00:00<00:00,  6.11it/s]
# 6 [TRAIN : NeuralNet] BIC Loss 0.694, F1 score 0.675: 100%|██████████| 43/43 [00:09<00:00,  4.60it/s]
# 6 [VALID : NeuralNet] BIC Loss 0.683, F1 score 0.682: 100%|██████████| 5/5 [00:00<00:00,  5.83it/s]
# 7 [TRAIN : NeuralNet] BIC Loss 0.685, F1 score 0.688: 100%|██████████| 43/43 [00:07<00:00,  5.69it/s]
# 7 [VALID : NeuralNet] BIC Loss 0.674, F1 score 0.702: 100%|██████████| 5/5 [00:00<00:00,  5.89it/s]
# 8 [TRAIN : NeuralNet] BIC Loss 0.677, F1 score 0.699: 100%|██████████| 43/43 [00:06<00:00,  6.18it/s]
# 20 [TRAIN : NeuralNet] BIC Loss 0.601, F1 score 0.779: 100%|██████████| 43/43 [00:07<00:00,  5.95it/s]
# 20 [VALID : NeuralNet] BIC Loss 0.591, F1 score 0.796: 100%|██████████| 5/5 [00:00<00:00,  5.91it/s]
# 21 [TRAIN : NeuralNet] BIC Loss 0.597, F1 score 0.783: 100%|██████████| 43/43 [00:07<00:00,  6.07it/s]
# 21 [VALID : NeuralNet] BIC Loss 0.586, F1 score 0.798: 100%|██████████| 5/5 [00:00<00:00,  6.35it/s]
# 22 [TRAIN : NeuralNet] BIC Loss 0.592, F1 score 0.786: 100%|██████████| 43/43 [00:06<00:00,  6.28it/s]
# 22 [VALID : NeuralNet] BIC Loss 0.582, F1 score 0.805: 100%|██████████| 5/5 [00:00<00:00,  6.34it/s]
# 23 [TRAIN : NeuralNet] BIC Loss 0.587, F1 score 0.789: 100%|██████████| 43/43 [00:06<00:00,  6.43it/s]
# 23 [VALID : NeuralNet] BIC Loss 0.577, F1 score 0.806: 100%|██████████| 5/5 [00:00<00:00,  6.58it/s]
# 24 [TRAIN : NeuralNet] BIC Loss 0.583, F1 score 0.792: 100%|██████████| 43/43 [00:06<00:00,  6.37it/s]
# 24 [VALID : NeuralNet] BIC Loss 0.573, F1 score 0.806: 100%|██████████| 5/5 [00:00<00:00,  6.51it/s]
# 25 [TRAIN : NeuralNet] BIC Loss 0.579, F1 score 0.793: 100%|██████████| 43/43 [00:06<00:00,  6.41it/s]
# 25 [VALID : NeuralNet] BIC Loss 0.568, F1 score 0.807: 100%|██████████| 5/5 [00:00<00:00,  6.51it/s]
# 26 [TRAIN : NeuralNet] BIC Loss 0.575, F1 score 0.794: 100%|██████████| 43/43 [00:06<00:00,  6.43it/s]
# 26 [VALID : NeuralNet] BIC Loss 0.564, F1 score 0.807: 100%|██████████| 5/5 [00:00<00:00,  6.32it/s]
# 27 [TRAIN : NeuralNet] BIC Loss 0.570, F1 score 0.795: 100%|██████████| 43/43 [00:06<00:00,  6.49it/s]
# 27 [VALID : NeuralNet] BIC Loss 0.560, F1 score 0.811: 100%|██████████| 5/5 [00:00<00:00,  6.44it/s]
# 28 [TRAIN : NeuralNet] BIC Loss 0.565, F1 score 0.798: 100%|██████████| 43/43 [00:06<00:00,  6.38it/s]
# 28 [VALID : NeuralNet] BIC Loss 0.555, F1 score 0.812: 100%|██████████| 5/5 [00:00<00:00,  6.59it/s]
# 29 [TRAIN : NeuralNet] BIC Loss 0.562, F1 score 0.798: 100%|██████████| 43/43 [00:06<00:00,  6.48it/s]
# 29 [VALID : NeuralNet] BIC Loss 0.551, F1 score 0.815: 100%|██████████| 5/5 [00:00<00:00,  6.40it/s]
# 30 [TRAIN : NeuralNet] BIC Loss 0.558, F1 score 0.801: 100%|██████████| 43/43 [00:06<00:00,  6.50it/s]
# 30 [VALID : NeuralNet] BIC Loss 0.547, F1 score 0.815: 100%|██████████| 5/5 [00:00<00:00,  6.58it/s]
# 31 [TRAIN : NeuralNet] BIC Loss 0.554, F1 score 0.801: 100%|██████████| 43/43 [00:07<00:00,  6.10it/s]
# 54 [VALID : NeuralNet] BIC Loss 0.458, F1 score 0.834: 100%|██████████| 5/5 [00:00<00:00,  6.19it/s]
# 55 [TRAIN : NeuralNet] BIC Loss 0.468, F1 score 0.832: 100%|██████████| 43/43 [00:06<00:00,  6.34it/s]
# 55 [VALID : NeuralNet] BIC Loss 0.454, F1 score 0.837: 100%|██████████| 5/5 [00:00<00:00,  6.09it/s]
# 56 [TRAIN : NeuralNet] BIC Loss 0.465, F1 score 0.833: 100%|██████████| 43/43 [00:06<00:00,  6.38it/s]
# 56 [VALID : NeuralNet] BIC Loss 0.452, F1 score 0.842: 100%|██████████| 5/5 [00:00<00:00,  6.54it/s]
# 57 [TRAIN : NeuralNet] BIC Loss 0.462, F1 score 0.836: 100%|██████████| 43/43 [00:06<00:00,  6.27it/s]
# 57 [VALID : NeuralNet] BIC Loss 0.448, F1 score 0.837: 100%|██████████| 5/5 [00:00<00:00,  6.45it/s]
# 58 [TRAIN : NeuralNet] BIC Loss 0.459, F1 score 0.835: 100%|██████████| 43/43 [00:06<00:00,  6.31it/s]
# 58 [VALID : NeuralNet] BIC Loss 0.445, F1 score 0.840: 100%|██████████| 5/5 [00:00<00:00,  6.58it/s]
# 59 [TRAIN : NeuralNet] BIC Loss 0.456, F1 score 0.838: 100%|██████████| 43/43 [00:06<00:00,  6.32it/s]
# 59 [VALID : NeuralNet] BIC Loss 0.442, F1 score 0.845: 100%|██████████| 5/5 [00:00<00:00,  6.46it/s]
# 60 [TRAIN : NeuralNet] BIC Loss 0.453, F1 score 0.837: 100%|██████████| 43/43 [00:06<00:00,  6.40it/s]
# 60 [VALID : NeuralNet] BIC Loss 0.439, F1 score 0.842: 100%|██████████| 5/5 [00:00<00:00,  6.41it/s]
# 61 [TRAIN : NeuralNet] BIC Loss 0.450, F1 score 0.839: 100%|██████████| 43/43 [00:06<00:00,  6.29it/s]
# 61 [VALID : NeuralNet] BIC Loss 0.437, F1 score 0.844: 100%|██████████| 5/5 [00:00<00:00,  6.33it/s]
# 62 [TRAIN : NeuralNet] BIC Loss 0.447, F1 score 0.840: 100%|██████████| 43/43 [00:06<00:00,  6.25it/s]
# 62 [VALID : NeuralNet] BIC Loss 0.434, F1 score 0.848: 100%|██████████| 5/5 [00:00<00:00,  6.35it/s]
# 63 [TRAIN : NeuralNet] BIC Loss 0.446, F1 score 0.840: 100%|██████████| 43/43 [00:06<00:00,  6.17it/s]
# 63 [VALID : NeuralNet] BIC Loss 0.431, F1 score 0.843: 100%|██████████| 5/5 [00:00<00:00,  5.79it/s]
# 64 [TRAIN : NeuralNet] BIC Loss 0.442, F1 score 0.841: 100%|██████████| 43/43 [00:07<00:00,  6.07it/s]
# 64 [VALID : NeuralNet] BIC Loss 0.428, F1 score 0.847: 100%|██████████| 5/5 [00:00<00:00,  5.97it/s]
# 65 [TRAIN : NeuralNet] BIC Loss 0.440, F1 score 0.840: 100%|██████████| 43/43 [00:06<00:00,  6.32it/s]
# 65 [VALID : NeuralNet] BIC Loss 0.426, F1 score 0.847: 100%|██████████| 5/5 [00:00<00:00,  6.09it/s]
# 66 [TRAIN : NeuralNet] BIC Loss 0.438, F1 score 0.842: 100%|██████████| 43/43 [00:06<00:00,  6.37it/s]
# 66 [VALID : NeuralNet] BIC Loss 0.423, F1 score 0.848: 100%|██████████| 5/5 [00:00<00:00,  6.37it/s]
# 67 [TRAIN : NeuralNet] BIC Loss 0.434, F1 score 0.843: 100%|██████████| 43/43 [00:06<00:00,  6.31it/s]
# 67 [VALID : NeuralNet] BIC Loss 0.426, F1 score 0.839: 100%|██████████| 5/5 [00:00<00:00,  6.48it/s]

# %% [markdown]
# ### Training vs validation loss

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

for _, row in results_df.iterrows():
    epochs = range(len(row["train_bce"]))
    plt.plot(epochs, row["train_bce"], label=f"{row['num_layers']} layers")

plt.xlabel("Epoch")
plt.ylabel("Train BCE")
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

for _, row in results_df.iterrows():
    epochs = range(len(row["valid_bce"]))
    plt.plot(epochs, row["valid_bce"], label=f"{row['num_layers']} layers")

plt.xlabel("Epoch")
plt.ylabel("Validation BCE")
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

for _, row in results_df.iterrows():
    epochs = range(len(row["train_f1"]))
    plt.plot(epochs, row["train_f1"], label=f"{row['num_layers']} layers")

plt.xlabel("Epoch")
plt.ylabel("Train F1")
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

for _, row in results_df.iterrows():
    epochs = range(len(row["valid_f1_"]))
    plt.plot(epochs, row["valid_f1_"], label=f"{row['num_layers']} layers")

plt.xlabel("Epoch")
plt.ylabel("Validation F1")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
mode = "TEST"
neuralnet_model.model.eval()

criterion = nn.BCELoss()
F1_score = BinaryF1Score()

loss_list = []
f1_score_list = []

testloader = DataLoader(test_set, batch_size=batch_size, shuffle=False, drop_last=True)
tpbar = tqdm(testloader)
for i, data in enumerate(tpbar):
    input_images, labels = data

    with torch.no_grad():
        predictions = neuralnet_model.model(input_images.view(batch_size, -1))

    loss = criterion(predictions, labels)
    loss_list.append(loss.item())

    f1_score = F1_score(predictions, labels)
    f1_score_list.append(f1_score.item())

    tpbar.set_description(
        "[%s : %s] BIC Loss %0.3f, F1 score %0.3f"
        % (
            mode,
            model_name,
            sum(loss_list) / len(loss_list),
            sum(f1_score_list) / len(f1_score_list),
        )
    )
# Out:
# [TEST : NeuralNet] BIC Loss 0.401, F1 score 0.857: 100%|██████████| 10/10 [00:00<00:00, 15.29it/s]

# %% [markdown]
# ## Q2. Extending the Neural Network & Selecting the Best Configuration (Validation Strategy)
#
# ![image-2.png](attachment:image-2.png)
# ### Validation F1
# - 1-layer model improves slowly and plateaus lower (~0.81).
# - 2-layer and 3-layer models converge faster and reach higher F1 (~0.85+).
# - 3-layer model does not outperform 2-layer.
#
# ![image.png](attachment:image.png)
# ### Validation BCE
# - 1-layer model maintains consistently higher loss.
# - 2-layer and 3-layer models both reduce loss significantly.
# - 2-layer model achieves better loss to 3-layer with fewer parameters.
#
#
#
# ### Why 2 Hidden Layers Is The Best Model?
#
#    - High validation F1 and Low validation BCE
#
#    - Fewer parameters than 3-layer model and lower computational cost
#
#    - 3-layer model does not provide meaningful performance gain. so this increased complexity without measurable benefit.
#
#    - Simpler architecture but more stable convergence
